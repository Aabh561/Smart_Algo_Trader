# %%
# 📱 Module 06: Send Live Trade Alert to Telegram using SmartAabhaBot

import requests

# ✅ Your bot details
bot_token = '7776273753:AAEvdTvjx2fCn78d4_UAZoQ3seNf41_MAI4'
chat_id = '6298447721'

# ✅ Trade alert content
stock = "AAPL"
signal = "BUY"
price = "186.42"

message = f"""
📢 Trade Alert (Smart Algo-Trader)

🧾 Stock: {stock}
📈 Signal: {signal}
💰 Price: ${price}
📅 Alert sent by SmartAabhaBot
"""

# ✅ Telegram API call
url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
data = {
    "chat_id": chat_id,
    "text": message
}

response = requests.post(url, data=data)

# ✅ Output result
if response.status_code == 200:
    print("✅ Telegram alert sent successfully!")
else:
    print(f"❌ Failed to send alert. Status code: {response.status_code}")
# Out:
# ✅ Telegram alert sent successfully!
